# %% [markdown]
# **Prompt:**
#
# # Recall that when a Hadamard gate is applied to a quantum state and the state is measured in the off/on basis, a close to 50/50 split emerges as a result of the state being in balanced superposition of off and on. How could this state possibly be modified to be in an imbalanced superposition?
#
# # Initialize a quantum circuit with one quantum bit and one classical bit, and using two unitary gates, put the state in an imbalanced superposition of off and on. Measure the state in the off/on basis. Which gate did you use as your second gate? What do you expect the results of the histogram to look like based on your choice of gates? What about the bloch vector? Plot the bloch vector and the histogram showing the results of your measurement, with a shot count of 1000.

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, transpile
import matplotlib as mpl
import numpy as np
from math import pi
from qiskit.visualization import plot_bloch_multivector, plot_histogram
from qiskit_aer import Aer

# %%
qc = QuantumCircuit(1, 1)

qc.h(0)
qc.ry(pi/4, 0)
statevector = plot_bloch_multivector(qc)
qc.measure(0, 0)
#qc.draw('mpl')

backend = Aer.get_backend('statevector_simulator')
job = backend.run(transpile(qc, backend), shots=1000)
result = job.result()
counts = result.get_counts()
plot_histogram(counts)

# %%
statevector
